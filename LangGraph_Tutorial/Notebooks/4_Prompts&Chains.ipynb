# %% [markdown]
# # **Prompts in langgraph**
# In this tutorial, we will learn how to use prompts in langgraph. We will create a simple graph that takes a topic as input and generates a post and a curated post as output. We will use the `ChatOpenAI` model to generate the post and the curated post.

# %%
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
import os
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("OpenAI API Key is set.")
else:
    raise ValueError("OpenAI API Key is not set.")
# Out:
# OpenAI API Key is set.

# %%
from langchain_ollama import OllamaLLM, ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = OllamaLLM(model="llama3.2")
# llm_ollama = ChatOllama(model="llama3.2")
# llm = ChatOllama(model="nemotron-3-nano:4b")
llm = ChatOllama(model="gemma3:1b")

# %%
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-5-mini")

# %%
from langchain_core.prompts import ChatPromptTemplate


my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# ### **Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
from IPython.display import display, Markdown

resp = chain.invoke({"topic": "The importance of data privacy in the digital age"}).content
display(Markdown(resp))
# Out:
# Okay, let’s craft a compelling social media post about data privacy! Here are a few options, tailored for different platforms and tones, with varying lengths and calls to action. I’ll give you a few variations to choose from.
#
# **Option 1 (Instagram - Visually Focused & Slightly Emotional)**
#
# **(Image: A calming, slightly blurred photo of a person looking at a screen with a gentle, thoughtful expression. Or a stylized graphic of a lock with data flowing out.)**
#
# “In today’s digital age, our lives are increasingly lived online. But with that convenience comes a crucial responsibility: data privacy. 🔒  Every click, share, and search reveals information – and that information can be valuable.  Protecting your data means safeguarding your identity, your privacy, and your future. ➡️ Let's make informed choices about *who* gets what.  #DataPrivacy #PrivacyMatters #DigitalSecurity #StaySafeOnline #PrivacyFirst”
#
# ...
