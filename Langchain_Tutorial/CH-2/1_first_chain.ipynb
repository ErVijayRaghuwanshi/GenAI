# %% [markdown]
# # **CHAINS In Langchain**

# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
# Out:
# Bro API KEY Variable exists

# %%
from langchain_ollama import OllamaLLM, ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = OllamaLLM(model="gemma4:e2b")
# llm_ollama = ChatOllama(model="llama3.2")
llm_ollama = ChatOllama(model="nemotron-3-nano:4b")

# %% [markdown]
# # **First Chain**

# %%
# TASK -1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# TASK - 2 [LLM]

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %%
chain = prompt_template | llm_ollama
chain.invoke({"input": "What is LangChain?"})
# Out:
# AIMessage(content='LangChain is an open‑source Python library (with Node.js and JavaScript ports) that makes it easier to build **large‑language‑model (LLM)-powered applications**.  \n\n### What the name means\n- **“Lang”** – language processing. LangChain focuses on natural‑language generation and understanding.\n- **“Chain”** – a chain or pipeline of components (e.g., an LLM, a memory module, a database query) that are linked together to compose a larger workflow.\n\n### Core ideas\n\n| Feature | What it does | Why it matters |\n|---------|--------------|----------------|\n| **Components** | Small building blocks like prompts, LLM calls, retrievers, aggregators, and post‑processing functions. | You can combine the best parts for any task (e.g., a chatbot that searches its own documents). |\n| **Chains / Agents** | Predefined sequences or higher‑level “agents” that orchestrate components based on data or prompts. | Saves you from writing boilerplate code; changes are localized. |\n| **Memory & Context Management** | Temporary and persistent state (e.g., retrieving recent user messages, remembering past conversations). | Enables coherent, session‑aware behavior without manually passing data around. |\n| **Vector Stores** | Integration with stores like Pinecone, Weaviate, PostgreSQL\u202fTS, Chroma, etc., to store embeddings of documents or vectors. | Allows memory that can be queried in O(log\u202fN). |\n| **Prompt Templates & Dynamic Prompting** | Filling prompts automatically using data retrieved from a vector store or agent output. | Produces more accurate, context‑aware results. |\n| **Agents (Tool‑Using)** | Decision loops where an LLM selects tools (e.g., browse, calculator) to answer questions. | Extends capabilities beyond simple retrieval‑augmented generation. |\n\n### Typical workflow\n\n1. **Retrieve relevant info** – Use a retriever that queries a vector store containing your documents.  \n2. **Generate** – Feed the retrieved snippets into an LLM via a prompt template (often using templating or function calls).  \n3. **Memory & State** – Keep context from past interactions so the conversation isn’t lost.  \n4. **Post‑process / Activate tools** – If needed, run custom code, call APIs, etc.\n\nAll of these steps can be assembled with a single `LangChain` chain (e.g., `RetrievalQA`, `ConversationalChain`) or programmatically defined via `llm`, `retriever`, `memory`, and other calls.\n\n### Why people use LangChain\n\n- **Rapid prototyping** – Write a chatbot in minutes instead of weeks.\n- **Reusability** – Share chains between projects; the same chain can work with different LLMs or data sources.\n- **Extensibility** – Plug in any Python module, REST API, or custom code as a tool/function.\n- **Composable pipelines** – Break down complex tasks into small “components” that can be swapped.\n\n### Example (Python)\n\n```python\nfrom langchain.llms import OpenAI   # could also use HuggingFace, Ollama, etc.\nfrom langchain.prompts import PromptTemplate\nfrom langchain.chains import RetrievalQA\n\n# 1️⃣ LLM\nllm = OpenAI(model="text-davinci-003")\n\n# 2️⃣ Template – inserts {{answer}} from the retrieval step\ntemplate = PromptTemplate(\n    input_variables=["context", "question"],\n    template="$context\\nQuestion: {question}\\nAnswer:"\n)\n\n# 3️⃣ Retrieval (example with a vector store)\nretriever = RetrievalRetriever(vectorstore=my_pinecone)\n\n# 4️⃣ Full chain – retrieves then calls LLM\nqa_chain = RetrievalQA.from_template(template, llm=llm, retriever=retreiver)\n\nanswer = qa_chain.run("What is the capital of Australia?")\nprint(answer)   # "Canberra"\n```\n\nThat’s essentially a “chain”: *retrieve → generate*.\n\n---\n\n**Bottom line:** LangChain provides the scaffolding for turning an LLM into flexible, context‑aware, multi‑tool applications while letting you focus on your domain logic rather than boilerplate plumbing.', additional_kwargs={}, response_metadata={'model': 'nemotron-3-nano:4b', 'created_at': '2026-08- ...

# %%
resp = _

# %%
from IPython.display import display, Markdown

display(Markdown(resp.content))
# Out:
# LangChain is an open‑source Python library (with Node.js and JavaScript ports) that makes it easier to build **large‑language‑model (LLM)-powered applications**.
#
# ### What the name means
# - **“Lang”** – language processing. LangChain focuses on natural‑language generation and understanding.
# - **“Chain”** – a chain or pipeline of components (e.g., an LLM, a memory module, a database query) that are linked together to compose a larger workflow.
#
# ### Core ideas
#
# | Feature | What it does | Why it matters |
# |---------|--------------|----------------|
# | **Components** | Small building blocks like prompts, LLM calls, retrievers, aggregators, and post‑processing functions. | You can combine the best parts for any task (e.g., a chatbot that searches its own documents). |
# | **Chains / Agents** | Predefined sequences or higher‑level “agents” that orchestrate components based on data or prompts. | Saves you from writing boilerplate code; changes are localized. |
# | **Memory & Context Management** | Temporary and persistent state (e.g., retrieving recent user messages, remembering past conversations). | Enables coherent, session‑aware behavior without manually passing data around. |
# | **Vector Stores** | Integration with stores like Pinecone, Weaviate, PostgreSQL TS, Chroma, etc., to store embeddings of documents or vectors. | Allows memory that can be queried in O(log N). |
# | **Prompt Templates & Dynamic Prompting** | Filling prompts automatically using data retrieved from a vector store or agent output. | Produces more accurate, context‑aware results. |
# | **Agents (Tool‑Using)** | Decision loops where an LLM selects tools (e.g., browse, calculator) to answer questions. | Extends capabilities beyond simple retrieval‑augmented generation. |
#
# ### Typical workflow
#
# 1. **Retrieve relevant info** – Use a retriever that queries a vector store containing your documents.
# 2. **Generate** – Feed the retrieved snippets into an LLM via a prompt template (often using templating or function calls).
# 3. **Memory & State** – Keep context from past interactions so the conversation isn’t lost.
# 4. **Post‑process / Activate tools** – If needed, run custom code, call APIs, etc.
#
# All of these steps can be assembled with a single `LangChain` chain (e.g., `RetrievalQA`, `ConversationalChain`) or programmatically defined via `llm`, `retriever`, `memory`, and other calls.
#
# ### Why people use LangChain
#
# - **Rapid prototyping** – Write a chatbot in minutes instead of weeks.
# - **Reusability** – Share chains between projects; the same chain can work with different LLMs or data sources.
# - **Extensibility** – Plug in any Python module, REST API, or custom code as a tool/function.
# - **Composable pipelines** – Break down complex tasks into small “components” that can be swapped.
#
# ### Example (Python)
#
# ```python
# from langchain.llms import OpenAI   # could also use HuggingFace, Ollama, etc.
# from langchain.prompts import PromptTemplate
# from langchain.chains import RetrievalQA
#
# # 1️⃣ LLM
# llm = OpenAI(model="text-davinci-003")
#
# # 2️⃣ Template – inserts {{answer}} from the retrieval step
# template = PromptTemplate(
#     input_variables=["context", "question"],
#     template="$context\nQuestion: {question}\nAnswer:"
# )
#
# # 3️⃣ Retrieval (example with a vector store)
# retriever = RetrievalRetriever(vectorstore=my_pinecone)
#
# # 4️⃣ Full chain – retrieves then calls LLM
# qa_chain = RetrievalQA.from_template(template, llm=llm, retriever=retreiver)
#
# answer = qa_chain.run("What is the capital of Australia?")
# print(answer)   # "Canberra"
# ```
#
# That’s essentially a “chain”: *retrieve → generate*.
#
# ---
#
# **Bottom line:** LangChain provides the scaffolding for turning an LLM into flexible, context‑aware, multi‑tool applications while letting you focus on your domain logic rather than boilerplate plumbing.

# %% [markdown]
# ### **Manual Invocation**

# %%
template = prompt_template.invoke({"input": "What is the capital of pak?"})

res = llm.invoke(template)

# final_result = res.content
res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 template = prompt_template.invoke({"input": "What is the capital of France?"})
#       2
# ----> 3 res = llm.invoke(template)
#       4
#       5 # final_result = res.content
#       6 res
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:384, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     373 @override
#     374 def invoke(
#     375     self,
#    (...)    380     **kwargs: Any,
#     381 ) -> str:
#     382     config = ensure_config(config)
#     383     return (
# --> 384         self.generate_prompt(
#     385             [self._convert_input(input)],
#     386             stop=stop,
#     387             callbacks=config.get("callbacks"),
#     388             tags=config.get("tags"),
#     389             metadata=config.get("metadata"),
#     390             run_name=config.get("run_name"),
#     391             run_id=config.pop("run_id", None),
#     392             **kwargs,
#     393         )
#     394         .generations[0][0]
#     395         .text
#     396     )
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:801, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     792 @override
#     793 def generate_prompt(
#     794     self,
#    (...)    798     **kwargs: Any,
#     799 ) -> LLMResult:
#     800     prompt_strings = [p.to_string() for p in prompts]
# --> 801     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:1031, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1012 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1013     run_managers = [
#    1014         callback_manager.on_llm_start(
#    1015             self._serialized,
#    (...)   1029         )
#    1030     ]
# -> 1031     return self._generate_helper(
#    1032         prompts,
#    1033         stop,
#    1034         run_managers,
#    1035         new_arg_supported=bool(new_arg_supported),
#    1036         **kwargs,
#    1037     )
#    1038 if len(missing_prompts) > 0:
#    1039     run_managers = [
#    1040         callback_managers[idx].on_llm_start(
#    1041             self._serialized,
#    (...)   1048         for idx in missing_prompt_idxs
#    1049     ]
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:827, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     816 def _generate_helper(
#     817     self,
#     818     prompts: list[str],
#    (...)    823     **kwargs: Any,
#     824 ) -> LLMResult:
#     825     try:
#     826         output = (
# --> 827             self._generate(
#     828                 prompts,
#     829                 stop=stop,
#     830                 # TODO: support multiple run managers
#     831                 run_manager=run_managers[0] if run_managers else None,
#     832                 **kwargs,
#     833             )
#     834             if new_arg_supported
#     835             else self._generate(prompts, stop=stop)
#     836         )
#     837     except BaseException as e:
#     838         for run_manager in run_managers:
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_ollama/llms.py:470, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     468 generations = []
#     469 for prompt in prompts:
# --> 470     final_chunk = self._stream_with_aggregation(
#     471         prompt,
#     472         stop=stop,
#     473         run_manager=run_manager,
#     474         verbose=self.verbose,
#     475         **kwargs,
#     476     )
#     477     generations.append([final_chunk])
#     478 return LLMResult(generations=generations)
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_ollama/llms.py:429, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     427 final_chunk = None
#     428 thinking_content = ""
# --> 429 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     430     if not isinstance(stream_resp, str):
#     431         if stream_resp.get("thinking"):
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_ollama/llms.py:373, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     368     msg = (
#     369         "Ollama sync client is not initialized. "
#     370         "Make sure the model was properly constructed."
#     371     )
#     372     raise RuntimeError(msg)
# --> 373 yield from self._client.generate(
#     374     **self._generate_params(prompt, stop=stop, **kwargs)
#     375 )
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/ollama/_client.py:184, in Client._request.<locals>.inner()
#     183 def inner():
# --> 184   with self._client.stream(*args, **kwargs) as r:
#     185     try:
#     186       r.raise_for_status()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)    853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)    866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Chain Invocation**

# %%
chain = prompt_template | llm_ollama | str_parser

chain.invoke({"input": "What is the capital of France?"})
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_core.runnables import RunnableSequence

chain_1 = RunnableSequence(prompt_template, llm_openai, str_parser)

chain_1.invoke("What is the capital of France?")
# Out:
# 'The capital of France is Paris.'
