# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
# Out:
# Bro API KEY Variable exists

# %% [markdown]
# # **CHAIN WITH CUSTOM RUNNABLE**

# %%
from langchain_ollama import OllamaLLM, ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = OllamaLLM(model="llama3.2")
# llm_ollama = ChatOllama(model="llama3.2")
llm_ollama = ChatOllama(model="nemotron-3-nano:4b")

# %%
# TASK -1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")])

# %%
# TASK - 2 [LLM]

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %%
# TASK - 4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)-> dict:

    return {"text" : text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK - 5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator. "),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 6 [Generate the Post]

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # TASK - 6 [Generate the Post]
# ----> 3 llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
#
# NameError: name 'ChatOpenAI' is not defined

# %%
# TASK - 7 [Str Parser]

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm_ollama | str_parser | dictionary_maker_runnable | prompt_post | llm_ollama | str_parser

chain.invoke("What is the capital of France?")
# Out:
# 'Here’s a polished, professional LinkedIn post that’s concise, value-driven, and fits the platform’s tone:\n\n---\n\n**Quick thought:**  \nThe capital of France is Paris.  \nSimple. True. Foundational knowledge that sparks curiosity.  \n\nIn a world of complex challenges, sometimes the most profound insights start with a single fact. 🌍  \n\n*What’s one fact you’d want to share today?*  \n👇 (Let’s keep learning together!)  \n\n#Leadership #KnowledgeIsPower #ContinuousLearning #Paris  \n\n---\n\n### Why this works for LinkedIn:\n1. **Professional tone** – Avoids sounding like a school assignment.  \n2. **Value-add** – Ties the fact to learning culture ("sparks curiosity," "foundational knowledge").  \n3. **Engagement hook** – Ends with a question to spark comments (LinkedIn’s goal).  \n4. **Subtle branding** – "KnowledgeIsPower" hashtag aligns with leadership themes.  \n5. **Clean** – Under 8 seconds to read (LinkedIn best practice).  \n\n*No overused phrases, no fluff, and it subtly positions you as someone who values simplicity and impact.* 😊'

# %%
resp = _

# %%
from IPython.display import display, Markdown

display(Markdown(resp))
# Out:
# Here’s a polished, professional LinkedIn post that’s concise, value-driven, and fits the platform’s tone:
#
# ---
#
# **Quick thought:**
# The capital of France is Paris.
# Simple. True. Foundational knowledge that sparks curiosity.
#
# In a world of complex challenges, sometimes the most profound insights start with a single fact. 🌍
#
# *What’s one fact you’d want to share today?*
# 👇 (Let’s keep learning together!)
#
# #Leadership #KnowledgeIsPower #ContinuousLearning #Paris
#
# ---
#
# ### Why this works for LinkedIn:
# 1. **Professional tone** – Avoids sounding like a school assignment.
# 2. **Value-add** – Ties the fact to learning culture ("sparks curiosity," "foundational knowledge").
# 3. **Engagement hook** – Ends with a question to spark comments (LinkedIn’s goal).
# 4. **Subtle branding** – "KnowledgeIsPower" hashtag aligns with leadership themes.
# 5. **Clean** – Under 8 seconds to read (LinkedIn best practice).
#
# *No overused phrases, no fluff, and it subtly positions you as someone who values simplicity and impact.* 😊
