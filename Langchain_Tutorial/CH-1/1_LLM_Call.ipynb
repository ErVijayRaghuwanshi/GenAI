# %% [markdown]
# # **LLM CALL**

# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       8
#       9 if os.environ.get("OPENAI_API_KEY"):
#      10     print("Bro API KEY Variable exists")
#      11 else:
# ---> 12     raise ValueError("OPENAI_API_KEY not found")
#      13
#
# ValueError: OPENAI_API_KEY not found

# %%
llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

llm_openai.invoke("Bro, tell me a fun fact").content
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
#       2
#       3 llm_openai.invoke("Bro, tell me a fun fact").content
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1335, in BaseChatOpenAI.validate_environment(self)
#    1321         self.http_async_client = _build_proxied_async_httpx_client(
#    1322             proxy=self.openai_proxy,
#    1323             verify=global_ssl_context,
#    1324             socket_options=resolved_socket_options,
#    1325         )
#    1326     async_specific = {
#    1327         "http_client": self.http_async_client
#    1328         or _get_default_async_httpx_client(
#    (...)   1333         "api_key": async_api_key_value,
#    1334     }
# -> 1335     self.root_async_client = openai.AsyncOpenAI(
#    1336         **client_params,
#    1337         **async_specific,  # type: ignore[arg-type]
#    1338     )
#    1339     self.async_client = self.root_async_client.chat.completions
#    1340 return self
#
# File ~/Documents/Programs/Repo/GenAI/.venv/lib/python3.13/site-packages/openai/_client.py:837, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     827 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     829 if (
#     830     provider_runtime is None
#     831     and _enforce_credentials
#    (...)    835     and self.admin_api_key is None
#     836 ):
# --> 837     raise OpenAIError(
#     838         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     839     )
#     841 if organization is None and provider_runtime is None:
#     842     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(model = "gpt-5-mini")

llm_openai.invoke("Hello, how are you?")
# Out:
# AIMessage(content="I'm doing well, thanks — how are you? How can I help you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 12, 'total_tokens': 38, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CukuJUAUbhIeWx4L3FGI81o2Ulqhl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8fb7-4e22-73a0-a36b-ee5c756b7d08-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 26, 'total_tokens': 38, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
